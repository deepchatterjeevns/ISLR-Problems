# %% [markdown]
# # Chapter 3 Problem 9

# %% [markdown]
# ## a.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
df = pd.DataFrame(pd.read_csv('data/auto.csv'))
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
g = sns.PairGrid(df)
g.map_upper(plt.scatter)
g.map_lower(plt.scatter)
g.map_diag(plt.hist)

# %% [markdown]
# ## b.

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.776260     -0.804443 -0.831739      0.422297
# cylinders    -0.776260   1.000000      0.950920  0.897017     -0.504061
# displacement -0.804443   0.950920      1.000000  0.933104     -0.544162
# weight       -0.831739   0.897017      0.933104  1.000000     -0.419502
# acceleration  0.422297  -0.504061     -0.544162 -0.419502      1.000000
# year          0.581469  -0.346717     -0.369804 -0.307900      0.282901
# origin        0.563698  -0.564972     -0.610664 -0.581265      0.210084
#
#                   year    origin
# mpg           0.581469  0.563698
# cylinders    -0.346717 -0.564972
# displacement -0.369804 -0.610664
# weight       -0.307900 -0.581265
# acceleration  0.282901  0.210084
# year          1.000000  0.184314
# origin        0.184314  1.000000

# %% [markdown]
# ## c.

# %%
df['horsepower'].head()
df['horsepower'].unique()
drop_list = df[df['horsepower'] == '?'].index
df = df.drop(drop_list)

# %%
model = smf.ols('mpg ~ cylinders + displacement+ horsepower +weight + acceleration + year + origin',data = df)
model = model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     252.4
# Date:                Mon, 30 Dec 2019   Prob (F-statistic):          2.04e-139
# Time:                        18:28:23   Log-Likelihood:                -1023.5
# No. Observations:                 392   AIC:                             2063.
# Df Residuals:                     384   BIC:                             2095.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## i.

# %% [markdown]
# Yes, there is a relationship between the predictors and the repsonse. The f-statistic is 252.4. Which is much larger than 1. Therefore, we can reject the null hypothesis.

# %% [markdown]
# ## ii.

# %% [markdown]
# displacement, weight, year, and origin are all significant.

# %% [markdown]
# ## iii.

# %% [markdown]
# The ccoefficient for the year variable suggests that, on average, when other variables are held constant, each additional year corresponds to an increase of 0.75 mpg.
